# %% [markdown]
# # This notebook will examine the RDS created in the data preperation section

# %%
from pathlib import Path

import pandas as pd
pd.options.display.max_rows = 1000
pd.options.display.max_columns = 100

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rds_Path = Path(r"C:\Users\cianw\Documents\dataAnalytics\CA2\Data\Datasets\referenceDataSet.csv")
rds = pd.read_csv(rds_Path)

# %%
rds.head(500)
# Out:
#      Unnamed: 0 subst_cat geo  TIME_PERIOD  harmRiskInd nace_r2  \
# 0             0      HRI1  AT         2011          102     NaN
# 1             1      HRI1  AT         2012          106     NaN
# 2             2      HRI1  AT         2013           92     NaN
# 3             3      HRI1  AT         2014           95     NaN
# 4             4      HRI1  AT         2015          101     NaN
# 5             5      HRI1  AT         2016          115     NaN
# 6             6      HRI1  AT         2017          116     NaN
# 7             7      HRI1  AT         2018          129     NaN
# 8             8      HRI1  AT         2019          121     NaN
# 9             9      HRI1  AT         2020          135     NaN
# 10           10      HRI1  BE         2011          102     NaN
# 11           11      HRI1  BE         2012          104    C103
# 12           12      HRI1  BE         2013           94    C103
# 13           13      HRI1  BE         2014          106    C103
# ...
